# %% [markdown]
# <a href="https://colab.research.google.com/github/DevAnand-debugger/Basics-of-python/blob/main/EDA_26_jan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name=Dev Anand

# %% [markdown]
# PRN=25070123039

# %% [markdown]
# Batch=A2

# %% [markdown]
# Unit 1

# %% [markdown]
# Basic Programs-Experiments

# %%
# First Python Program/string
print("Hello,Welcome to Python Programming")
# Out:
# Hello,Welcome to Python Programming

# %%
a="Hello"
print(a)
# Out:
# Hello

# %%
print("Hello,Welcome to python Programming")
# Out:
# Hello,Welcome to python Programming

# %%
# Comments
#This is a comment
print("Hello ,world!")
# Out:
# Hello ,world!

# %%
print("Hello World!")
print("Have a good day")
print("Learning Python is fun!")

# %%
print("Hello");print("How are you ?");print("Bye bye!")
# Out:
# Hello
# How are you ?
# Bye bye!

# %%
# Print numbers
a=3
print(a)
print(358)
print(500.200)
# Out:
# 3
# 358
# 500.2

# %%
#Variables
x=5
y="hello world!"
print(x)
print(y)
# Out:
# 5
# hello world!

# %%
#case sensitive
a=4
A="sally"
print(a)
print(A)
# Out:
# 4
# sally

# %%
#Many Values to Multiple Variables
x,y,z = "Orange","Banana","Cherry"

print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
# Basic Arithematic operations
a = 10
b = 5

print("Addition =", a + b)
print("Substraction =", a-b)
print("Multiplication =",a*b)
print("division =",a/b)
# Out:
# Addition = 15
# Substraction = 5
# Multiplication = 50
# division = 2.0

# %%
#understading Data Types
x = 10
Y = 3.14
Z = "Python"
A = True
C=3+2j

print(type(x))
print(type(Y))
print(type(Z))
print(type(A))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
# Taking Input from User
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Name:" , name)
print("Age:", age)
# Out:
# Enter your name: dev anand
# Enter your age: 18
# Name: dev anand
# Age: 18

# %%
marks1 = int(input("Enter your maths marks: "))
marks2 = int(input("Enter your science marks: "))
marks3 = int(input("Enter your hindi marks: "))
marks4 = int(input("Enter your english: "))
marks5 = int(input("Enter your social studies: "))

sum= marks1+marks2+marks3+marks4+marks5
average= sum/5
print("Sum=",sum)

print("Average=",average)
# Out:
# Enter your maths marks: 1
# Enter your science marks: 2
# Enter your hindi marks: 3
# Enter your english: 4
# Enter your social studies: 5
# Sum= 15
# Average= 3.0

# %%
radius=int(input("enter radius: "))

area=3.14*radius*radius

print("Area=",area)
# Out:
# enter radius: 5
# Area= 78.5

# %%
length = int(input("enter length: "))
breadth = int(input("enter breadth: "))
area = length * breadth
print("Area=",area)
# Out:
# enter length: 2
# enter breadth: 3
# Area= 6

# %%
length = int(input("enter length: "))
breadth = int(input("enter breadth: "))
perimeter = 2*(length + breadth)
print("Perimeter=",perimeter)
# Out:
# enter length: 2
# enter breadth: 3
# Perimeter= 10

# %%
a= int(input("enter first number: "))
b= int(input("enter second number: "))

print("Addition =", a + b)
print("Substraction =", a-b)
print("Multiplication =",a*b)
print("division =",a/b)
# Out:
# enter first number: 10
# enter second number: 5
# Addition = 15
# Substraction = 5
# Multiplication = 50
# division = 2.0
